# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# %%
# Read the City 
city_data_df = pd.read_csv(city_data_to_load)
city_data_df.head(10)
# Out:
#             city  driver_count   type
# 0    Richardfort            38  Urban
# 1   Williamsstad            59  Urban
# 2    Port Angela            67  Urban
# 3     Rodneyfort            34  Urban
# 4    West Robert            39  Urban
# 5   West Anthony            70  Urban
# 6    West Angela            48  Urban
# 7  Martinezhaven            25  Urban
# 8      Karenberg            22  Urban
# 9    Barajasview            26  Urban

# %%
## Read the Ride Data
ride_data_df = pd.read_csv(ride_data_to_load)
ride_data_df.head(10)
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5        South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6       New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7        Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8     South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9       North Jasmine  2019-03-09 06:26:29  42.81  5327642267789

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type. 
#use the groupby() function to create a Series of data that has the type of city as the index, then apply the count() method to the "ride_id" column.

total_ride_city_df = pyber_data_df.groupby(["type"]).count()["ride_id"]
total_ride_city_df = total_ride_city_df.rename("Total Rides")
total_ride_city_df
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: Total Rides, dtype: int64

# %%
# 2. Get the total drivers for each city type
#use the groupby() function to create a Series of data that has the type of city as the index, then apply the sum() method to the "driver_count" column.

# %%
total_drivers_city_df = pyber_data_df.groupby(["city","type"]).mean()["driver_count"]
total_drivers_city_df = total_drivers_city_df.groupby(["type"]).sum()
total_drivers_city_df = total_drivers_city_df.rename("Total Drivers")
total_drivers_city_df
# Out:
# type
# Rural         78.0
# Suburban     490.0
# Urban       2405.0
# Name: Total Drivers, dtype: float64

# %%
#  3. Get the total amount of fares for each city type
#use the groupby() function to create a Series of data that has the type of city as the index, 
#then apply the sum()method to the "fare" column.
total_fare_city_df = pyber_data_df.groupby(["type"]).sum()["fare"]
total_fare_city_df = total_fare_city_df.rename("Total Fares")
total_fare_city_df
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: Total Fares, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
#calculate the average fare per ride by city type by dividing the sum of all the fares by the total rides.
avg_fare_ride_df = pd.Series(fare_city_df / ride_city_df)
avg_fare_ride_df = avg_fare_ride_df.rename("Average Fare Per Ride")
avg_fare_ride_df
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# Name: Average Fare Per Ride, dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
#calculate the average fare per driver by city type by dividing the sum of all the fares by the total drivers.
avg_fare_driver_df = pd.Series(fare_city_df / drivers_city_df)
avg_fare_driver_df = avg_fare_driver_df.rename("Average Fare Per Driver")
avg_fare_driver_df
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# Name: Average Fare Per Driver, dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
#create a PyBer summary DataFrame with all the data gathered from Steps 1-5, using the column names shown below

pyber_summary_df = pd.merge(ride_city_df, total_drivers_city_df, on=["type"])
pyber_summary_df = pd.merge(pyber_summary_df, total_fare_city_df, on=["type"])
pyber_summary_df = pd.merge(pyber_summary_df, avg_fare_ride_df, on=["type"])
pyber_summary_df = pd.merge(pyber_summary_df, avg_fare_driver_df, on=["type"])
pyber_summary_df
# Out:
#           ride_id  Total Drivers  Total Fares  Average Fare Per Ride  \
# type
# Rural         125           78.0      4327.93              34.623440
# Suburban      625          490.0     19356.33              30.970128
# Urban        1625         2405.0     39854.38              24.525772
#
#           Average Fare Per Driver
# type
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None

pyber_summary_df
# Out:
#           ride_id  Total Drivers  Total Fares  Average Fare Per Ride  \
# Rural         125           78.0      4327.93              34.623440
# Suburban      625          490.0     19356.33              30.970128
# Urban        1625         2405.0     39854.38              24.525772
#
#           Average Fare Per Driver
# Rural                   55.486282
# Suburban                39.502714
# Urban                   16.571468

# %%
#  8. Format the columns.
pyber_summary_df = pyber_summary_df.rename(columns={"ride_id":"Total Rides"})

pyber_summary_df["Total Rides"] = pyber_summary_df["Total Rides"].map("{:,.0f}".format)
pyber_summary_df["Total Drivers"] = pyber_summary_df["Total Drivers"].map("{:,.0f}".format)
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Ride"] = pyber_summary_df["Average Fare Per Ride"].map("${:.2f}".format)
pyber_summary_df["Average Fare per Driver"] = pyber_summary_df["Average Fare Per Driver"].map("${:.2f}".format)

pyber_summary_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [116], in <cell line: 4>()
#       1 #  8. Format the columns.
#       2 pyber_summary_df = pyber_summary_df.rename(columns={"ride_id":"Total Rides"})
# ----> 4 pyber_summary_df["Total Rides"] = pyber_summary_df["Total Rides"].map("{:,.2}".format)
#       5 pyber_summary_df["Total Drivers"] = pyber_summary_df["Total Drivers"].map("{:,.2}".format)
#       6 pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2}".format)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.9/site-packages/pandas/core/series.py:4237, in Series.map(self, arg, na_action)
#    4162 def map(self, arg, na_action=None) -> Series:
#    4163     """
#    4164     Map values of Series according to an input mapping or function.
#    4165
#    (...)
#    4235     dtype: object
#    4236     """
# ...

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame

# Display the data table for preview
pyber_data_df.head(10)

##Funtions
#pivot() and resample()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5        South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6       New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7        Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8     South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9       North Jasmine  2019-03-09 06:26:29  42.81  5327642267789
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban
# 5            10  Urban
# 6            44  Urban
# 7            21  Urban
# 8             4  Urban
# ...

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.

#create a new DataFrame with multiple indices using the groupby() function on the "type" and "date" columns of 
#the pyber_data_df DataFrame, then apply the sum() method on the "fare" column to show the total fare amount for each date.
# Adding a list of values with keys to create a new DataFrame.
date_city_df = pyber_data_df.groupby(["type","date"]).sum()["fare"]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()

#use the provided code snippet to reset the index. 
#This is needed to use the pivot() function in the next step (Step 3).
date_city_df = pyber_data_df.reset_index()

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 

#use the pivot() function to convert the DataFrame from the previous step so that the index 
#is the "date," each column is a city "type," and the values are the "fare."
date_pivot_df = date_city_df.pivot(index="date", columns="type", values="fare")
date_pivot_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
import datetime as dt

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.

#create a new DataFrame by using the loc method on the following date range: 2019-01-01 through 2019-04-28.
start = dt.datetime(2019,1,1)
end = dt.datetime(2019,4,29)
#unrate['DATE'] = pd.to_datatime(unrate['DATE'])
date_pivot_df.index = pd.to_datetime(date_pivot_df.index)

# %%
date_range_df = date_pivot_df.loc[(date_pivot_df.index > start) &
                                (date_pivot_df.index < end)]
date_range_df

#used this for help: https://www.kaggle.com/questions-and-answers/177520
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-28 14:28:36    NaN       NaN  11.46
# 2019-04-28 16:29:16    NaN       NaN  36.42
# 2019-04-28 17:26:52    NaN       NaN  31.43
# 2019-04-28 17:38:09    NaN     34.87    NaN
# 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)

#use the provided code snippet to reset the index of the DataFrame from the previous step (Step 4) 
#to a datetime data type. This is necessary to use the resample() method in Step 7.

# %%
# 7. Check that the datatype for the index is datetime using df.info()

#use the provided code snippet, df.info(), to check that the "date" is a datetime data type.
date_range_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2196 entries, 2019-01-01 00:08:16 to 2019-04-28 19:35:03
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     114 non-null    float64
#  1   Suburban  573 non-null    float64
#  2   Urban     1509 non-null   float64
# dtypes: float64(3)
# memory usage: 68.6 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.

#create a new DataFrame by applying the resample() function to the DataFrame you modified in Step 5. 
#Resample the data in weekly bins, then apply the sum() method to get the total fares for each week.

week_range_df = date_range_df.resample("W").sum()
week_range_df
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1357.75  2238.29

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

##Finally, in Step 8, graph the resampled DataFrame from Step 7 using the object-oriented interface method 
#and the df.plot() method, as well as the Matplotlib "fivethirtyeight" graph style code snippet provided in the 
#starter code. Annotate the y-axis label and the title, then use the appropriate code to save the figure as 
#PyBer_fare_summary.png in your "analysis" folder.
week_range_df.plot(ylabel="Fare ($US)", xlabel="",
                  title="Total Fare by City Type",
                  grid=True, figsize=(25, 6))

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

#Save Figure
plt.savefig("Analysis/Fig8.png")
